# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

from sklearn import svm

# %%
data = []
iter_list = [20,48,75,95,99]

for i in iter_list:
    path = 'data/Ref_Factor_' + str(i) +'.csv'
    data.append(pd.read_csv(path))

#maybe make this a np.arrary instead of a list

# %%
df_20 = np.array( data[0]['Wvl'] <= 1000)

# %%
print(len(data))
# Out:
# 5

# %%
print(data[0]['Wvl']<=1000 and data[0]['Reflect. %'] < 100)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-48-d6eed42551fa> in <module>()
# ----> 1 print(data[0]['Wvl']<=1000 and data[0]['Reflect. %'] < 100)
#
# /opt/conda/lib/python3.5/site-packages/pandas/core/generic.py in __nonzero__(self)
#     915         raise ValueError("The truth value of a {0} is ambiguous. "
#     916                          "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
# --> 917                          .format(self.__class__.__name__))
#     918
#     919     __bool__ = __nonzero__
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
print(data[0]['Reflect. %'] < 100)
#data[0].columns.values
# Out:
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
# 5        True
# 6        True
# 7        True
# 8        True
# 9        True
# 10       True
# 11       True
# 12       True
# 13       True
# 14       True
# 15       True
# 16       True
# 17       True
# 18       True
# 19       True
# 20       True
# 21       True
# 22       True
# 23       True
# 24       True
# 25       True
# 26       True
# 27       True
# 28       True
# 29       True
#         ...
# 994      True
# 995      True
# 996      True
# 997      True
# 998     False
# 999     False
# 1000    False
# 1001    False
# 1002    False
# 1003     True
# 1004    False
# 1005     True
# 1006     True
# 1007    False
# 1008     True
# 1009    False
# 1010    False
# 1011    False
# 1012    False
# 1013    False
# 1014     True
# 1015    False
# 1016    False
# 1017     True
# 1018    False
# 1019     True
# 1020    False
# 1021    False
# 1022    False
# 1023    False
# ...

# %%
#data.head()
#for j in iter_list:
data_1000 = []
for i in range(len(data)):
    data_1000.append(data[i](data[i]['Wvl']<=1000 and data[i]['Reflect. %'] < 100))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-46-433e23b1d917> in <module>()
#       3 data_1000 = []
#       4 for i in range(len(data)):
# ----> 5     data_1000.append(data[i](data[i]['Wvl']<=1000 and data[i]['Reflect. %'] < 100))
#
# /opt/conda/lib/python3.5/site-packages/pandas/core/generic.py in __nonzero__(self)
#     915         raise ValueError("The truth value of a {0} is ambiguous. "
#     916                          "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
# --> 917                          .format(self.__class__.__name__))
#     918
#     919     __bool__ = __nonzero__
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
print(data_1000[0].shape)
print(data_1000[1].shape)
print(data_1000[2].shape)
print(data_1000[3].shape)
print(data_1000[4].shape)
# Out:
# (513, 7)
# (513, 7)
# (513, 7)
# (513, 7)
# (513, 7)

# %%
plt.figure()
plt.plot(data_1000[0]['Wvl'], data_1000[0]['Rad. (Ref.)'], 'r.')
plt.plot(data_1000[1]['Wvl'], data_1000[1]['Rad. (Ref.)'], color='black', marker ='.')
plt.plot(data_1000[2]['Wvl'], data_1000[2]['Rad. (Ref.)'], 'y.')
plt.plot(data_1000[3]['Wvl'], data_1000[3]['Rad. (Ref.)'], 'g.')
plt.plot(data_1000[4]['Wvl'], data_1000[4]['Rad. (Ref.)'], 'b.')
plt.show
# Out:
# <function matplotlib.pyplot.show>
